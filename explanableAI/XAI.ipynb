# %%
# !pip install explainx
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting explainx
#   Downloading explainx-2.407.tar.gz (792 kB)
#      |████████████████████████████████| 792 kB 7.4 MB/s
# Collecting jupyter_dash==0.2.1.post1
#   Downloading jupyter_dash-0.2.1.post1-py3-none-any.whl (45 kB)
#      |████████████████████████████████| 45 kB 2.0 MB/s
# Collecting dash_bootstrap_components==0.10.2
#   Downloading dash-bootstrap-components-0.10.2.tar.gz (107 kB)
#      |████████████████████████████████| 107 kB 40.8 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Collecting dash==1.12.0
#   Downloading dash-1.12.0.tar.gz (66 kB)
#      |████████████████████████████████| 66 kB 5.0 MB/s
# Collecting dash_core_components==1.10.0
#   Downloading dash_core_components-1.10.0.tar.gz (3.4 MB)
#      |████████████████████████████████| 3.4 MB 46.1 MB/s
# Collecting dash_html_components==1.0.3
#   Downloading dash_html_components-1.0.3.tar.gz (187 kB)
#      |████████████████████████████████| 187 kB 47.8 MB/s
# Collecting plotly==4.5.1
#   Downloading plotly-4.5.1-py2.py3-none-any.whl (7.1 MB)
#      |████████████████████████████████| 7.1 MB 35.8 MB/s
# Collecting dash_table==4.7.0
#   Downloading dash_table-4.7.0.tar.gz (1.8 MB)
#      |████████████████████████████████| 1.8 MB 41.2 MB/s
# Collecting pandas==1.0.4
#   Downloading pandas-1.0.4-cp37-cp37m-manylinux1_x86_64.whl (10.1 MB)
#      |████████████████████████████████| 10.1 MB 49.9 MB/s
# Collecting numpy==1.18.1
#   Downloading numpy-1.18.1-cp37-cp37m-manylinux1_x86_64.whl (20.1 MB)
#      |████████████████████████████████| 20.1 MB 7.3 MB/s
# Collecting cvxopt==1.2.4
#   Downloading cvxopt-1.2.4-cp37-cp37m-manylinux1_x86_64.whl (11.6 MB)
#      |████████████████████████████████| 11.6 MB 47.4 MB/s
# Collecting scikit-learn==0.22.1
#   Downloading scikit_learn-0.22.1-cp37-cp37m-manylinux1_x86_64.whl (7.0 MB)
#      |████████████████████████████████| 7.0 MB 37.5 MB/s
# Collecting scipy==1.4.1
#   Downloading scipy-1.4.1-cp37-cp37m-manylinux1_x86_64.whl (26.1 MB)
#      |████████████████████████████████| 26.1 MB 1.2 MB/s
# Collecting pandasql==0.7.3
#   Downloading pandasql-0.7.3.tar.gz (26 kB)
# Collecting tqdm==4.47.0
#   Downloading tqdm-4.47.0-py2.py3-none-any.whl (66 kB)
#      |████████████████████████████████| 66 kB 5.7 MB/s
# Collecting dash-editor-components==0.0.2
#   Downloading dash_editor_components-0.0.2.tar.gz (38 kB)
# Collecting shap==0.34.0
#   Downloading shap-0.34.0.tar.gz (264 kB)
#      |████████████████████████████████| 264 kB 67.6 MB/s
# Collecting dash_daq==0.5.0
#   Downloading dash_daq-0.5.0.tar.gz (642 kB)
#      |████████████████████████████████| 642 kB 50.6 MB/s
# Collecting pyrebase
#   Downloading Pyrebase-3.0.27-py3-none-any.whl (9.6 kB)
# Collecting h2o==3.30.1.3
#   Downloading h2o-3.30.1.3.tar.gz (129.4 MB)
#      |████████████████████████████████| 129.4 MB 46 kB/s
# Requirement already satisfied: pytest in /usr/local/lib/python3.7/dist-packages (from explainx) (3.6.4)
# Requirement already satisfied: Flask>=1.0.2 in /usr/local/lib/python3.7/dist-packages (from dash==1.12.0->explainx) (1.1.4)
# Collecting flask-compress
#   Downloading Flask_Compress-1.12-py3-none-any.whl (7.9 kB)
# Collecting dash_renderer==1.4.1
#   Downloading dash_renderer-1.4.1.tar.gz (1.2 MB)
#      |████████████████████████████████| 1.2 MB 50.1 MB/s
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from dash==1.12.0->explainx) (0.16.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from h2o==3.30.1.3->explainx) (2.23.0)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.7/dist-packages (from h2o==3.30.1.3->explainx) (0.8.10)
# Collecting colorama>=0.3.8
#   Downloading colorama-0.4.5-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.7/dist-packages (from jupyter_dash==0.2.1.post1->explainx) (5.3.4)
# Requirement already satisfied: ipython in /usr/local/lib/python3.7/dist-packages (from jupyter_dash==0.2.1.post1->explainx) (7.9.0)
# Collecting ansi2html
#   Downloading ansi2html-1.8.0-py3-none-any.whl (16 kB)
# Collecting retrying
#   Downloading retrying-1.3.3.tar.gz (10 kB)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas==1.0.4->explainx) (2022.2.1)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.7/dist-packages (from pandas==1.0.4->explainx) (2.8.2)
# Requirement already satisfied: sqlalchemy in /usr/local/lib/python3.7/dist-packages (from pandasql==0.7.3->explainx) (1.4.41)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from plotly==4.5.1->explainx) (1.15.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn==0.22.1->explainx) (1.1.0)
# Requirement already satisfied: Werkzeug<2.0,>=0.15 in /usr/local/lib/python3.7/dist-packages (from Flask>=1.0.2->dash==1.12.0->explainx) (1.0.1)
# Requirement already satisfied: itsdangerous<2.0,>=0.24 in /usr/local/lib/python3.7/dist-packages (from Flask>=1.0.2->dash==1.12.0->explainx) (1.1.0)
# Requirement already satisfied: Jinja2<3.0,>=2.10.1 in /usr/local/lib/python3.7/dist-packages (from Flask>=1.0.2->dash==1.12.0->explainx) (2.11.3)
# Requirement already satisfied: click<8.0,>=5.1 in /usr/local/lib/python3.7/dist-packages (from Flask>=1.0.2->dash==1.12.0->explainx) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from Jinja2<3.0,>=2.10.1->Flask>=1.0.2->dash==1.12.0->explainx) (2.0.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from ansi2html->jupyter_dash==0.2.1.post1->explainx) (4.12.0)
# Collecting brotli
#   Downloading Brotli-1.0.9-cp37-cp37m-manylinux1_x86_64.whl (357 kB)
#      |████████████████████████████████| 357 kB 55.7 MB/s
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->ansi2html->jupyter_dash==0.2.1.post1->explainx) (3.8.1)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->ansi2html->jupyter_dash==0.2.1.post1->explainx) (4.1.1)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.7/dist-packages (from ipykernel->jupyter_dash==0.2.1.post1->explainx) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.7/dist-packages (from ipykernel->jupyter_dash==0.2.1.post1->explainx) (5.1.1)
# Requirement already satisfied: traitlets>=4.1.0 in /usr/local/lib/python3.7/dist-packages (from ipykernel->jupyter_dash==0.2.1.post1->explainx) (5.1.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.7/dist-packages (from ipython->jupyter_dash==0.2.1.post1->explainx) (0.2.0)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.7/dist-packages (from ipython->jupyter_dash==0.2.1.post1->explainx) (4.8.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.7/dist-packages (from ipython->jupyter_dash==0.2.1.post1->explainx) (57.4.0)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from ipython->jupyter_dash==0.2.1.post1->explainx) (2.6.1)
# Collecting jedi>=0.10
#   Downloading jedi-0.18.1-py2.py3-none-any.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 48.0 MB/s
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from ipython->jupyter_dash==0.2.1.post1->explainx) (2.0.10)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from ipython->jupyter_dash==0.2.1.post1->explainx) (0.7.5)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from ipython->jupyter_dash==0.2.1.post1->explainx) (4.4.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.7/dist-packages (from jedi>=0.10->ipython->jupyter_dash==0.2.1.post1->explainx) (0.8.3)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython->jupyter_dash==0.2.1.post1->explainx) (0.2.5)
# Requirement already satisfied: jupyter-core>=4.6.0 in /usr/local/lib/python3.7/dist-packages (from jupyter-client->ipykernel->jupyter_dash==0.2.1.post1->explainx) (4.11.1)
# Requirement already satisfied: pyzmq>=13 in /usr/local/lib/python3.7/dist-packages (from jupyter-client->ipykernel->jupyter_dash==0.2.1.post1->explainx) (23.2.1)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.7/dist-packages (from pexpect->ipython->jupyter_dash==0.2.1.post1->explainx) (0.7.0)
# Collecting python-jwt==2.0.1
#   Downloading python_jwt-2.0.1-py2.py3-none-any.whl (8.8 kB)
# Collecting gcloud==0.17.0
#   Downloading gcloud-0.17.0.tar.gz (458 kB)
#      |████████████████████████████████| 458 kB 50.9 MB/s
# Collecting requests
#   Downloading requests-2.11.1-py2.py3-none-any.whl (514 kB)
#      |████████████████████████████████| 514 kB 50.5 MB/s
# Collecting pycryptodome==3.4.3
#   Downloading pycryptodome-3.4.3.tar.gz (6.5 MB)
#      |████████████████████████████████| 6.5 MB 31.9 MB/s
# Collecting oauth2client==3.0.0
#   Downloading oauth2client-3.0.0.tar.gz (77 kB)
#      |████████████████████████████████| 77 kB 6.3 MB/s
# Collecting requests-toolbelt==0.7.0
#   Downloading requests_toolbelt-0.7.0-py2.py3-none-any.whl (52 kB)
#      |████████████████████████████████| 52 kB 1.2 MB/s
# Requirement already satisfied: httplib2>=0.9.1 in /usr/local/lib/python3.7/dist-packages (from gcloud==0.17.0->pyrebase->explainx) (0.17.4)
# Requirement already satisfied: googleapis-common-protos in /usr/local/lib/python3.7/dist-packages (from gcloud==0.17.0->pyrebase->explainx) (1.56.4)
# Requirement already satisfied: protobuf!=3.0.0.b2.post1,>=3.0.0b2 in /usr/local/lib/python3.7/dist-packages (from gcloud==0.17.0->pyrebase->explainx) (3.17.3)
# Requirement already satisfied: pyasn1>=0.1.7 in /usr/local/lib/python3.7/dist-packages (from oauth2client==3.0.0->pyrebase->explainx) (0.4.8)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in /usr/local/lib/python3.7/dist-packages (from oauth2client==3.0.0->pyrebase->explainx) (0.2.8)
# Requirement already satisfied: rsa>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from oauth2client==3.0.0->pyrebase->explainx) (4.9)
# Collecting jws>=0.1.3
#   Downloading jws-0.1.3.tar.gz (8.1 kB)
# Requirement already satisfied: pluggy<0.8,>=0.5 in /usr/local/lib/python3.7/dist-packages (from pytest->explainx) (0.7.1)
# Requirement already satisfied: py>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from pytest->explainx) (1.11.0)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.7/dist-packages (from pytest->explainx) (22.1.0)
# Requirement already satisfied: more-itertools>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from pytest->explainx) (8.14.0)
# Requirement already satisfied: atomicwrites>=1.0 in /usr/local/lib/python3.7/dist-packages (from pytest->explainx) (1.4.1)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.7/dist-packages (from sqlalchemy->pandasql==0.7.3->explainx) (1.1.3)
# Building wheels for collected packages: explainx, dash, dash-bootstrap-components, dash-core-components, dash-daq, dash-editor-components, dash-html-components, dash-renderer, dash-table, h2o, pandasql, shap, retrying, gcloud, oauth2client, pycryptodome, jws
#   Building wheel for explainx (setup.py) ... done
#   Created wheel for explainx: filename=explainx-2.407-py3-none-any.whl size=821022 sha256=e11131973d003486b195651a4f247d2d212dce4304c7a3151376b89f0f2cb4b3
#   Stored in directory: /root/.cache/pip/wheels/68/9f/99/133e9a26b49c918256577be43b13e965f78eca3983aa8e8cf5
#   Building wheel for dash (setup.py) ... done
#   Created wheel for dash: filename=dash-1.12.0-py3-none-any.whl size=73901 sha256=77741b1e9a7565215b6a295e45e7bb314c5c30c19f3586745e8b32c406cee713
#   Stored in directory: /root/.cache/pip/wheels/83/5a/bb/71b5ab781de27039924ebc8b7670714ae5c9a436c9c9100954
#   Building wheel for dash-bootstrap-components (PEP 517) ... done
#   Created wheel for dash-bootstrap-components: filename=dash_bootstrap_components-0.10.2-py3-none-any.whl size=179430 sha256=d243ac2e7409ce24e2db13e75336091651cc41b46403efdaaf844d8ee908f91a
#   Stored in directory: /root/.cache/pip/wheels/42/57/d1/f9eb4a20e4ef7cbfd8292d622e21022b01a337ab510be4657e
#   Building wheel for dash-core-components (setup.py) ... done
#   Created wheel for dash-core-components: filename=dash_core_components-1.10.0-py3-none-any.whl size=3454756 sha256=9652ef19e5ddcc321dcc9ca55055dc1496cd243f2ee1848fbbea864c326ac898
#   Stored in directory: /root/.cache/pip/wheels/82/4a/c7/399a824e6ff98cfe06a4aa16f2b14441b9aad98a6be9e2cc47
#   Building wheel for dash-daq (setup.py) ... done
#   Created wheel for dash-daq: filename=dash_daq-0.5.0-py3-none-any.whl size=669714 sha256=b823a9de70332a7ec1416e9d19aa91e46b24b9704295d62b89c31879ea7ec286
#   Stored in directory: /root/.cache/pip/wheels/fe/54/53/a8d448db5592874db4313240571ca2c069e55f6a6b29bf5847
#   Building wheel for dash-editor-components (setup.py) ... done
#   Created wheel for dash-editor-components: filename=dash_editor_components-0.0.2-py3-none-any.whl size=41163 sha256=525b941224e9400617fe25f4b0e19e11cbf517dcebdb409026549898c415ad8e
#   Stored in directory: /root/.cache/pip/wheels/fb/eb/3f/0279d7cdb00f785818be5a9c8f98d8d0a8ab719bee32bdc504
#   Building wheel for dash-html-components (setup.py) ... done
#   Created wheel for dash-html-components: filename=dash_html_components-1.0.3-py3-none-any.whl size=427324 sha256=a9f56453000b274d757cfa7075169a585ed20a522b2f5bd4a945b8d5fb33bb0e
#   Stored in directory: /root/.cache/pip/wheels/36/34/f9/c3d147461b28467d5bbd14d255be66f6728a1580ff9fbebece
#   Building wheel for dash-renderer (setup.py) ... done
#   Created wheel for dash-renderer: filename=dash_renderer-1.4.1-py3-none-any.whl size=1165596 sha256=771052e924a8ef4227882e0db0a5dff4cd111f6780916d98b591ac5fb37e9914
#   Stored in directory: /root/.cache/pip/wheels/58/74/07/ccdc4b119cc0314c5fead949457463176dfe3fb5bb86bb09c2
#   Building wheel for dash-table (setup.py) ... done
#   Created wheel for dash-table: filename=dash_table-4.7.0-py3-none-any.whl size=1777564 sha256=99efe6fd03eb1b9c16a82670841a4002a7c20c2a13448542751d43567b0d9dd7
#   Stored in directory: /root/.cache/pip/wheels/d0/74/84/5a72b6f628aaa86352ebaee87c2ce151b7e610e85af7e9a506
#   Building wheel for h2o (setup.py) ... done
#   Created wheel for h2o: filename=h2o-3.30.1.3-py2.py3-none-any.whl size=129446676 sha256=7a68b4932caad34296a083ccf96268123b33f7f28fd904bf61a72b5531fc7694
#   Stored in directory: /root/.cache/pip/wheels/c4/08/f0/1b00ab7f2ec7e81f6d51890e1f37665c06d7e32a31e69bcf50
#   Building wheel for pandasql (setup.py) ... done
#   Created wheel for pandasql: filename=pandasql-0.7.3-py3-none-any.whl size=26784 sha256=7b3402a235fbc08e18445821f2a977416f56bf8812a3732d15a5f386d5b4ad36
#   Stored in directory: /root/.cache/pip/wheels/5c/4b/ec/41f4e116c8053c3654e2c2a47c62b4fca34cc67ef7b55deb7f
#   Building wheel for shap (setup.py) ... done
#   Created wheel for shap: filename=shap-0.34.0-cp37-cp37m-linux_x86_64.whl size=384450 sha256=8ed186f0ecb104fc12006bb6157f70fcf6d2e888e2ca5b16175a5aac5f8447c0
#   Stored in directory: /root/.cache/pip/wheels/05/86/23/2c22a86fb2ba700382f20e1dbe536e211b3b1578aecc8adfac
#   Building wheel for retrying (setup.py) ... done
#   Created wheel for retrying: filename=retrying-1.3.3-py3-none-any.whl size=11447 sha256=73b0446c18fc6ce2c5454ffcd04ebdab7395ddaa283320d32c66102c2785671d
#   Stored in directory: /root/.cache/pip/wheels/f9/8d/8d/f6af3f7f9eea3553bc2fe6d53e4b287dad18b06a861ac56ddf
#   Building wheel for gcloud (setup.py) ... done
#   Created wheel for gcloud: filename=gcloud-0.17.0-py3-none-any.whl size=638015 sha256=1f5d25bcc235388d7e4db8cce369384d5b7c9c40350352b8e4367b976fe7da2e
#   Stored in directory: /root/.cache/pip/wheels/76/10/90/62a8de50d755940978e1473ed4ce4b579664fcc16077d0dc99
#   Building wheel for oauth2client (setup.py) ... done
#   Created wheel for oauth2client: filename=oauth2client-3.0.0-py3-none-any.whl size=106375 sha256=383f0ddad0c22da8b0f562862282925a6985be183cced0659d5ebd1702689179
#   Stored in directory: /root/.cache/pip/wheels/86/73/7a/3b3f76a2142176605ff38fbca574327962c71e25a43197a4c1
#   Building wheel for pycryptodome (setup.py) ... done
#   Created wheel for pycryptodome: filename=pycryptodome-3.4.3-cp37-cp37m-linux_x86_64.whl size=6814307 sha256=f84e240989d11ced91dfa8842a6ad720465d137cd7cf2fe5423325a8720fb559
#   Stored in directory: /root/.cache/pip/wheels/f3/83/08/de4131c0bbbbafa5bf3bd64cb0e86d40bed3ee43f3ff307112
#   Building wheel for jws (setup.py) ... done
#   Created wheel for jws: filename=jws-0.1.3-py3-none-any.whl size=9411 sha256=6b03009f871328d5c04e504d5d65db2f46d27501db09870f3b52d38e5caa32ec
#   Stored in directory: /root/.cache/pip/wheels/2e/ff/95/daf0797fca284304b39ee45749e750fdcdcaa081d46dc8fd99
# Successfully built explainx dash dash-bootstrap-components dash-core-components dash-daq dash-editor-components dash-html-components dash-renderer dash-table h2o pandasql shap retrying gcloud oauth2client pycryptodome jws
# Installing collected packages: retrying, numpy, jedi, brotli, scipy, requests, plotly, oauth2client, jws, flask-compress, dash-table, dash-renderer, dash-html-components, dash-core-components, tqdm, scikit-learn, requests-toolbelt, python-jwt, pycryptodome, pandas, gcloud, dash, colorama, ansi2html, shap, pyrebase, pandasql, jupyter-dash, h2o, dash-editor-components, dash-daq, dash-bootstrap-components, cvxopt, explainx
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.21.6
#     Uninstalling numpy-1.21.6:
#       Successfully uninstalled numpy-1.21.6
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.7.3
#     Uninstalling scipy-1.7.3:
#       Successfully uninstalled scipy-1.7.3
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
#   Attempting uninstall: plotly
#     Found existing installation: plotly 5.5.0
#     Uninstalling plotly-5.5.0:
#       Successfully uninstalled plotly-5.5.0
#   Attempting uninstall: oauth2client
#     Found existing installation: oauth2client 4.1.3
#     Uninstalling oauth2client-4.1.3:
#       Successfully uninstalled oauth2client-4.1.3
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.64.1
#     Uninstalling tqdm-4.64.1:
#       Successfully uninstalled tqdm-4.64.1
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.0.2
#     Uninstalling scikit-learn-1.0.2:
#       Successfully uninstalled scikit-learn-1.0.2
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.3.5
#     Uninstalling pandas-1.3.5:
#       Successfully uninstalled pandas-1.3.5
#   Attempting uninstall: cvxopt
#     Found existing installation: cvxopt 1.3.0
#     Uninstalling cvxopt-1.3.0:
#       Successfully uninstalled cvxopt-1.3.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# yellowbrick 1.5 requires scikit-learn>=1.0.0, but you have scikit-learn 0.22.1 which is incompatible.
# xarray 0.20.2 requires pandas>=1.1, but you have pandas 1.0.4 which is incompatible.
# xarray-einstats 0.2.2 requires numpy>=1.21, but you have numpy 1.18.1 which is incompatible.
# tensorflow 2.8.2+zzzcolab20220719082949 requires numpy>=1.20, but you have numpy 1.18.1 which is incompatible.
# tensorflow-datasets 4.6.0 requires requests>=2.19.0, but you have requests 2.11.1 which is incompatible.
# tensorboard 2.8.0 requires requests<3,>=2.21.0, but you have requests 2.11.1 which is incompatible.
# tables 3.7.0 requires numpy>=1.19.0, but you have numpy 1.18.1 which is incompatible.
# spacy 3.4.1 requires requests<3.0.0,>=2.13.0, but you have requests 2.11.1 which is incompatible.
# pydrive 1.3.1 requires oauth2client>=4.0.0, but you have oauth2client 3.0.0 which is incompatible.
# pooch 1.6.0 requires requests>=2.19.0, but you have requests 2.11.1 which is incompatible.
# plotnine 0.8.0 requires numpy>=1.19.0, but you have numpy 1.18.1 which is incompatible.
# plotnine 0.8.0 requires pandas>=1.1.0, but you have pandas 1.0.4 which is incompatible.
# plotnine 0.8.0 requires scipy>=1.5.0, but you have scipy 1.4.1 which is incompatible.
# panel 0.12.1 requires tqdm>=4.48.0, but you have tqdm 4.47.0 which is incompatible.
# pandas-datareader 0.9.0 requires requests>=2.19.0, but you have requests 2.11.1 which is incompatible.
# mizani 0.7.3 requires pandas>=1.1.0, but you have pandas 1.0.4 which is incompatible.
# kapre 0.3.7 requires numpy>=1.18.5, but you have numpy 1.18.1 which is incompatible.
# jaxlib 0.3.15+cuda11.cudnn805 requires numpy>=1.19, but you have numpy 1.18.1 which is incompatible.
# jaxlib 0.3.15+cuda11.cudnn805 requires scipy>=1.5, but you have scipy 1.4.1 which is incompatible.
# jax 0.3.17 requires numpy>=1.20, but you have numpy 1.18.1 which is incompatible.
# jax 0.3.17 requires scipy>=1.5, but you have scipy 1.4.1 which is incompatible.
# imbalanced-learn 0.8.1 requires scikit-learn>=0.24, but you have scikit-learn 0.22.1 which is incompatible.
# google-colab 1.0.0 requires pandas>=1.1.0, but you have pandas 1.0.4 which is incompatible.
# google-colab 1.0.0 requires requests>=2.23.0, but you have requests 2.11.1 which is incompatible.
# google-api-core 1.31.6 requires requests<3.0.0dev,>=2.18.0, but you have requests 2.11.1 which is incompatible.
# cmdstanpy 1.0.7 requires numpy>=1.21, but you have numpy 1.18.1 which is incompatible.
# Successfully installed ansi2html-1.8.0 brotli-1.0.9 colorama-0.4.5 cvxopt-1.2.4 dash-1.12.0 dash-bootstrap-components-0.10.2 dash-core-components-1.10.0 dash-daq-0.5.0 dash-editor-components-0.0.2 dash-html-components-1.0.3 dash-renderer-1.4.1 dash-table-4.7.0 explainx-2.407 flask-compress-1.12 gcloud-0.17.0 h2o-3.30.1.3 jedi-0.18.1 jupyter-dash-0.2.1.post1 jws-0.1.3 numpy-1.18.1 oauth2client-3.0.0 pandas-1.0.4 pandasql-0.7.3 plotly-4.5.1 pycryptodome-3.4.3 pyrebase-3.0.27 python-jwt-2.0.1 requests-2.11.1 requests-toolbelt-0.7.0 retrying-1.3.3 scikit-learn-0.22.1 scipy-1.4.1 shap-0.34.0 tqdm-4.47.0

# %%
# !pip3 uninstall numpy
# !pip3 install numpy  -I
# Out:
# Found existing installation: numpy 1.18.1
# Uninstalling numpy-1.18.1:
#   Would remove:
#     /usr/local/bin/f2py
#     /usr/local/bin/f2py3
#     /usr/local/bin/f2py3.7
#     /usr/local/lib/python3.7/dist-packages/numpy-1.18.1.dist-info/*
#     /usr/local/lib/python3.7/dist-packages/numpy/*
# Proceed (y/n)? y
#   Successfully uninstalled numpy-1.18.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting numpy
#   Downloading numpy-1.21.6-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (15.7 MB)
#      |████████████████████████████████| 15.7 MB 201 kB/s
# Installing collected packages: numpy
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# yellowbrick 1.5 requires scikit-learn>=1.0.0, but you have scikit-learn 0.22.1 which is incompatible.
# xarray 0.20.2 requires pandas>=1.1, but you have pandas 1.0.4 which is incompatible.
# tensorflow-datasets 4.6.0 requires requests>=2.19.0, but you have requests 2.11.1 which is incompatible.
# tensorboard 2.8.0 requires requests<3,>=2.21.0, but you have requests 2.11.1 which is incompatible.
# spacy 3.4.1 requires requests<3.0.0,>=2.13.0, but you have requests 2.11.1 which is incompatible.
# plotnine 0.8.0 requires pandas>=1.1.0, but you have pandas 1.0.4 which is incompatible.
# plotnine 0.8.0 requires scipy>=1.5.0, but you have scipy 1.4.1 which is incompatible.
# pandas-datareader 0.9.0 requires requests>=2.19.0, but you have requests 2.11.1 which is incompatible.
# mizani 0.7.3 requires pandas>=1.1.0, but you have pandas 1.0.4 which is incompatible.
# jaxlib 0.3.15+cuda11.cudnn805 requires scipy>=1.5, but you have scipy 1.4.1 which is incompatible.
# jax 0.3.17 requires scipy>=1.5, but you have scipy 1.4.1 which is incompatible.
# imbalanced-learn 0.8.1 requires scikit-learn>=0.24, but you have scikit-learn 0.22.1 which is incompatible.
# google-colab 1.0.0 requires pandas>=1.1.0, but you have pandas 1.0.4 which is incompatible.
# google-colab 1.0.0 requires requests>=2.23.0, but you have requests 2.11.1 which is incompatible.
# explainx 2.407 requires numpy==1.18.1, but you have numpy 1.21.6 which is incompatible.
# Successfully installed numpy-1.21.6

# %%
from explainx import * 
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

# %%
from google.colab import drive
from google.colab import files
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('data.csv', dtype=np.float64)
y = np.asarray(df['TOTAL VALUE'] )
y = y.reshape(y.shape[0],1)
feature_cols = df.columns.to_list()
feature_cols.remove('TOTAL VALUE')
x = np.asarray(df[feature_cols])

# %%
# Load Dataset: X_Data, Y_Data 
# X_Data = Pandas DataFrame
# Y_Data = Numpy Array or List

X_data,Y_data = explainx.dataset_heloc()

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X_data,Y_data, test_size=0.3, random_state=0)

# %%
# Train a RandomForest Model
model = RandomForestClassifier()
model.fit(X_train, Y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
explainx.ai(X_test, Y_test, model, model_name="randomforest")
# Out:
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# Dash app running on http://127.0.0.1:50997/
# True
